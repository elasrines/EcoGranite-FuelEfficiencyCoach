# %% [markdown]
# System Prompt
#
# You are EcoGranite, an IBM Granite–powered driving efficiency coach.
# Your job is to analyze OBD-II trip summaries and give clear, safe, non-judgmental guidance
# to help a driver reduce fuel consumption, improve smoothness, and prevent engine wear.
#
# Follow these rules:
# - Be encouraging and practical.
# - Avoid blaming language.
# - Give 3–5 specific suggestions.
# - Use short paragraphs or bullet points.

# %% [markdown]
# User prompt
#
# Here is a driving trip summary:
#
# - Average speed: {avg_speed_kmh} km/h
# - Average RPM: {avg_rpm}
# - Average fuel consumption: {avg_fuel_l100km} L/100km
# - High RPM at low speed events: {high_rpm_low_speed_pct}%
# - Long idling: {long_idle_pct}%
# - Acceleration events: {accel_events}
# - Braking events: {brake_events}
#
# Please provide:
# 1. A 4–6 sentence overview of the user’s driving efficiency.
# 2. A bullet list of personalized coaching suggestions.
# 3. A final short “key takeaway”.

# %% [markdown]
# Short Feedback prompt
# User prompt
#
# Based on this trip summary, give me VERY short coaching feedback (2 lines max):
#
# - Avg speed: {avg_speed_kmh} km/h
# - Avg RPM: {avg_rpm}
# - Fuel: {avg_fuel_l100km}
# - High RPM/Low Speed: {high_rpm_low_speed_pct}%
# - Idling: {long_idle_pct}%

# %% [markdown]
# Component-Specific Feedback (RPM, Idling, or Braking)
# User prompt
#
# Provide targeted coaching on ONLY the following component: {component}
#
# Trip stats:
# - High RPM at low speed: {high_rpm_low_speed_pct}%
# - Long idling: {long_idle_pct}%
# - Accel/Brake cycles: {accel_events}/{brake_events}
#
# Format:
# - 2 sentences explaining the behavior
# - 2–3 tips to improve
#
# Where {component} ∈ "RPM" | "Idling" | "Acceleration/Braking"

# %% [markdown]
# “Explain Like I’m New” Prompt (beginner-friendly)
# User prompt
#
# Explain the driver’s efficiency in a simple, friendly way for a beginner.
#
# Trip:
# - Avg speed: {avg_speed_kmh}
# - RPM: {avg_rpm}
# - Fuel: {avg_fuel_l100km}
# - Idling: {long_idle_pct}%
#
# Avoid technical jargon. Keep it gentle and supportive.

# %%
#Imports + load trip summaries
import os
import json
import time
import pandas as pd
import requests

# Load trip-level stats you generated earlier
trip_summary = pd.read_csv("../data/trip_summary_enriched.csv")

print(trip_summary.shape)
display(trip_summary.head())
# Out:
# (75, 16)
#                                    Trip  Avg_Speed_kmh      Avg_RPM  \
# 0   2017-07-10_Seat_Leon_KA_KA_Stau.csv      14.455887   940.928115
# 1   2017-07-11_Seat_Leon_KA_KA_Stau.csv      23.052541  1037.744883
# 2  2017-07-11_Seat_Leon_KA_S_Normal.csv      68.238275  1583.488220
# 3    2017-07-11_Seat_Leon_S_RT_Frei.csv      58.304813  1445.053577
# 4  2017-07-12_Seat_Leon_RT_S_Normal.csv      52.877656  1416.844637
#
#    Avg_Fuel_L/100km  HighRPM_LowSpeed_%  Long_Idle_Time_%  Accel_Events  \
# 0          0.472057                0.01             14.25           340
# 1          0.414721                0.01             19.80           421
# 2          0.275587                0.01              2.59          1289
# 3          0.268645                0.01              8.29           627
# 4          0.260331                0.00              1.74          1169
#
#    Brake_Events  Eco_Score Trip_Label  \
# 0           421  52.618155   Moderate
# 1           444  55.683479   Moderate
# 2          1180  64.944615   Moderate
# 3           704  74.307621  Efficient
# 4          1172  68.480285   Moderate
#
#                                   Main_Issue  \
# 0             Main issue: Fuel use (−33 pts)
# 1             Main issue: Fuel use (−26 pts)
# 2  Main issue: Acceleration events (−13 pts)
# 3              Main issue: Fuel use (−8 pts)
# 4       Main issue: Braking events (−12 pts)
#
#                                   Second_Issue  \
# 0                Second issue: Idling (−4 pts)
# 1                Second issue: Idling (−6 pts)
# 2       Second issue: Braking events (−12 pts)
# 3        Second issue: Braking events (−7 pts)
# 4  Second issue: Acceleration events (−12 pts)
#
#                                     What_Went_Well_1  \
# 0  Long idle time is only 14.2% – good anticipati...
# 1  Long idle time is only 19.8% – good anticipati...
# 2  Average fuel consumption is only 0.28 L/100km ...
# 3  Average fuel consumption is only 0.27 L/100km ...
# 4  Average fuel consumption is only 0.26 L/100km ...
#
#                                     What_Went_Well_2  \
# 0  Very little time was spent at high RPM and low...
# 1  Very little time was spent at high RPM and low...
# 2  Long idle time is only 2.6% – good anticipatio...
# 3  Long idle time is only 8.3% – good anticipatio...
# 4  Long idle time is only 1.7% – good anticipatio...
#
#                                 What_Could_Improve_1  \
# 0  Average fuel consumption is 0.47 L/100km – con...
# 1  Average fuel consumption is 0.41 L/100km – con...
# 2  There were 1289 acceleration and 1180 braking ...
# 3  There were 627 acceleration and 704 braking ev...
# 4  There were 1169 acceleration and 1172 braking ...
#
#                                 What_Could_Improve_2
# 0  340 acceleration and 421 braking events – typi...
# 1  There were 421 acceleration and 444 braking ev...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
def build_trip_prompt(row):
    return f"""
You are writing coaching text for the EcoGranite dashboard.

Important rules:
- Use the dashboard assessment below as the source of truth.
- Do not contradict the provided issues or strengths.
- Do not say fuel use is good if the dashboard says fuel use is bad.
- Use the exact metric values provided.
- Return plain text only.
- Do not use markdown.
- Do not use asterisks.
- Leave one blank line between sections.
- Use exactly these section headers:
Overview:
Coaching Suggestions:
Key Takeaway:

Dashboard assessment:
- Eco score: {row['Eco_Score']}
- Trip classification: {row['Trip_Label']}
- Main issue: {row['Main_Issue']}
- Second issue: {row['Second_Issue']}

Trip metrics:
- Average speed: {row['Avg_Speed_kmh']:.1f} km/h
- Average RPM: {row['Avg_RPM']:.0f}
- Average fuel consumption: {row['Avg_Fuel_L/100km']:.2f} L/100km
- High RPM at low speed events: {row['HighRPM_LowSpeed_%']:.2f}%
- Long idling: {row['Long_Idle_Time_%']:.2f}%
- Acceleration events: {int(row['Accel_Events'])}
- Braking events: {int(row['Brake_Events'])}

What went well:
- {row['What_Went_Well_1']}
- {row['What_Went_Well_2']}

What could improve:
- {row['What_Could_Improve_1']}
- {row['What_Could_Improve_2']}

Write:
1. An Overview of 3 to 4 sentences.
2. 4 bullet coaching suggestions.
3. A Key Takeaway of 1 sentence.

Do not invent new problems.
Do not change the meaning of the dashboard assessment.
"""

# %%
#Get IAM access token
from dotenv import load_dotenv
load_dotenv()

import os
API_KEY = os.getenv("WATSONX_API_KEY")
if not API_KEY:
    raise ValueError("WATSONX_API_KEY not found.")


def get_iam_access_token(api_key: str) -> str:
    iam_url = "https://iam.cloud.ibm.com/identity/token"
    headers = {"Content-Type": "application/x-www-form-urlencoded"}
    data = {
        "grant_type": "urn:ibm:params:oauth:grant-type:apikey",
        "apikey": api_key
    }

    r = requests.post(iam_url, headers=headers, data=data)
    if r.status_code != 200:
        raise Exception(f"IAM token error {r.status_code}: {r.text}")

    return r.json()["access_token"]

access_token = get_iam_access_token(API_KEY)
print("✅ Got IAM access token")
# Out:
# ✅ Got IAM access token

# %%
#Granite chat call function
WATSONX_CHAT_URL = "https://us-south.ml.cloud.ibm.com/ml/v1/text/chat?version=2023-05-29"
PROJECT_ID = "852aeb95-062b-40a1-b2fa-da7a22b9dba4"
MODEL_ID = "ibm/granite-4-h-small"

def call_granite(prompt_text, access_token, temperature=0.2, max_tokens=350):
    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json",
        "Authorization": f"Bearer {access_token}"
    }

    body = {
        "messages": [
            {
                "role": "system",
                "content": (
                    "You are EcoGranite, a fuel-efficiency driving coach. "
                    "Give supportive, practical eco-driving feedback."
                )
            },
            {"role": "user", "content": prompt_text}
        ],
        "project_id": PROJECT_ID,
        "model_id": MODEL_ID,
        "temperature": temperature,
        "max_tokens": max_tokens
    }

    r = requests.post(WATSONX_CHAT_URL, json=body, headers=headers)
    if r.status_code != 200:
        raise Exception(f"Granite error {r.status_code}: {r.text}")

    return r.json()["choices"][0]["message"]["content"]

# %%
#Test on 1–3 trips first
sample_trips = trip_summary.head(3)

for _, row in sample_trips.iterrows():
    prompt = build_trip_prompt(row)
    feedback = call_granite(prompt, access_token)

    print("="*80)
    print("Trip:", row.Trip)
    print(feedback)
# Out:
# ================================================================================
# Trip: 2017-07-10_Seat_Leon_KA_KA_Stau.csv
# Overview:
# Your eco-driving score of 52.6 indicates there is room for improvement in fuel efficiency. The main areas to focus on are reducing fuel consumption and minimizing idling time. With an average fuel consumption of 0.47 L/100km and 14.25% of the trip spent idling, there are clear opportunities to optimize your driving habits. By addressing these issues, you can enhance your eco-driving performance and reduce your environmental impact.
#
# Coaching Suggestions:
# - Aim to smooth out your acceleration to reduce the 340 acceleration events, which can help lower fuel consumption.
# - Work on minimizing unnecessary braking by anticipating traffic flow and maintaining a steady speed, addressing the 421 braking events.
# - Reduce idling time by turning off the engine when stationary for more than a minute, targeting the 14.25% long idling duration.
# - Focus on maintaining lower RPMs, especially at lower speeds, to improve fuel efficiency and reduce the average fuel consumption of 0.47 L/100km.
#
# Key Takeaway:
# By smoothing acceleration, minimizing braking, reducing idling, and maintaining lower RPMs, you can significantly improve your eco-driving score and fuel efficiency.
# ================================================================================
# Trip: 2017-07-11_Seat_Leon_KA_KA_Stau.csv
# Overview:
# Your eco-driving performance is moderate, with room for improvement in fuel efficiency and driving smoothness. The main areas to focus on are reducing fuel consumption and minimizing idling time. You demonstrate good anticipation of stops and efficient gear selection, as evidenced by low high RPM events. However, there is potential to improve by adopting smoother acceleration and braking techniques.
#
# Coaching Suggestions:
# - Aim to reduce average fuel consumption by practicing smoother acceleration and maintaining lower RPMs, especially at lower speeds.
# - Minimize idling time by turning off the engine when stopped for more than a few seconds, which will help decrease fuel waste and emissions.
# - Reduce the number of acceleration and braking events by anticipating traffic flow and adjusting speed gradually, leading to a smoother driving experience.
# - Maintain a consistent speed when possible, using cruise control on highways to optimize fuel efficiency and reduce unnecessary acceleration.
#
# Key Takeaway:
# By focusing on smoother acceleration, lower RPMs, and minimizing idling, you can significantly improve your eco-driving score and fuel efficiency.
# ================================================================================
# Trip: 2017-07-11_Seat_Leon_KA_S_Normal.csv
# Overview:
# Your eco-driving score of 64.9 indicates moderate fuel efficiency for this trip. While your average fuel consumption of 0.28 L/100km is quite efficient for your vehicle, there is room for improvement in driving style. The main issues are a high number of acceleration events (1289) and braking events (1180), which suggest opportunities for smoother, more anticipatory driving. Maintaining your low idle time of 2.6% is commendable.
#
# Coaching Suggestions:
# - Focus on smoother acceleration by gradually increasing speed and avoiding rapid throttle inputs.
# - Anticipate stops and traffic to reduce the need for hard braking, allowing your vehicle to coast to a stop when possible.
# - Maintain a steady speed whenever possible, using cruise control on highways to help optimize fuel efficiency.
# - Monitor your RPM and aim to shift gears at lower RPMs to reduce engine load and improve fuel economy.
#
# Key Takeaway:
# By adopting a smoother, more anticipatory driving style with gradual acceleration and reduced braking, you can further improve your eco-driving score and fuel efficiency.

# %%
#Run on all trips + save JSON
results = []

for i, (_, row) in enumerate(trip_summary.iterrows()):
    prompt = build_trip_prompt(row)

    try:
        feedback = call_granite(prompt, access_token)
    except Exception as e:
        feedback = f"ERROR: {e}"

    results.append({
        "Trip": row.Trip,
        "prompt": prompt.strip(),
        "feedback": feedback.strip()
    })

    # small pause to avoid rate limits
    if (i + 1) % 5 == 0:
        time.sleep(1)

len(results)
# Out:
# 75

# %%
#export
out_path = "../data/granite_trip_feedback.json"

with open(out_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print(f"✅ Saved Granite feedback to {out_path}")
# Out:
# ✅ Saved Granite feedback to ../data/granite_trip_feedback.json
